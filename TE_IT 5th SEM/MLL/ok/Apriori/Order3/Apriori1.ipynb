# %%
import pandas as pd
import numpy as np

# %%
# !pip install mlxtend
# Out:
# ...
#                                               0.0/1.4 MB ? eta -:--:--
#      -------                                  0.3/1.4 MB 8.6 MB/s eta 0:00:01
#      ---------------------                    0.8/1.4 MB 12.0 MB/s eta 0:00:01
#      -------------------------------------    1.4/1.4 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 10.2 MB/s eta 0:00:00
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv(r"D:\ml dataset\LP-1 Dataset\Apriori\Oder3.csv")

# %%
df
# Out:
#        TransactionNo          Items          DateTime    Daypart  DayType
# 0                  1          Bread   10/30/2016 9:58    Morning  Weekend
# 1                  2   Scandinavian  10/30/2016 10:05    Morning  Weekend
# 2                  2   Scandinavian  10/30/2016 10:05    Morning  Weekend
# 3                  3  Hot chocolate  10/30/2016 10:07    Morning  Weekend
# 4                  3            Jam  10/30/2016 10:07    Morning  Weekend
# ...              ...            ...               ...        ...      ...
# 20502           9682         Coffee    9/4/2017 14:32  Afternoon  Weekend
# 20503           9682            Tea    9/4/2017 14:32  Afternoon  Weekend
# 20504           9683         Coffee    9/4/2017 14:57  Afternoon  Weekend
# 20505           9683         Pastry    9/4/2017 14:57  Afternoon  Weekend
# 20506           9684      Smoothies    9/4/2017 15:04  Afternoon  Weekend
#
# [20507 rows x 5 columns]

# %%
te = TransactionEncoder()

# %%
x = te.fit_transform(df)

# %%
x
# Out:
# array([[False, False,  True, ...,  True,  True, False],
#        [False,  True, False, ...,  True,  True, False],
#        [ True, False, False, ..., False,  True, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
data = pd.DataFrame(x,columns=te.columns_)

# %%
len(data)
# Out:
# 20507

# %%
data.head()
# Out:
#        D      I      N      T      a      c      e      i      m      n  \
# 0  False  False   True   True   True   True  False   True  False   True
# 1  False   True  False  False  False  False   True  False   True  False
# 2   True  False  False   True   True  False   True   True   True  False
# 3   True  False  False  False   True  False  False  False  False  False
# 4   True  False  False   True   True  False   True  False  False  False
#
#        o      p      r      s      t      y
# 0   True  False   True   True   True  False
# 1  False  False  False   True   True  False
# 2  False  False  False  False   True  False
# 3  False   True   True  False   True   True
# 4  False   True  False  False  False   True

# %%
data
# Out:
#            D      I      N      T      a      c      e      i      m      n  \
# 0      False  False   True   True   True   True  False   True  False   True
# 1      False   True  False  False  False  False   True  False   True  False
# 2       True  False  False   True   True  False   True   True   True  False
# 3       True  False  False  False   True  False  False  False  False  False
# 4       True  False  False   True   True  False   True  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 20502  False  False  False  False  False  False  False  False  False  False
# 20503  False  False  False  False  False  False  False  False  False  False
# 20504  False  False  False  False  False  False  False  False  False  False
# 20505  False  False  False  False  False  False  False  False  False  False
# 20506  False  False  False  False  False  False  False  False  False  False
#
#            o      p      r      s      t      y
# ...

# %%
from mlxtend.frequent_patterns import apriori,association_rules

# %%
freq_itemset = apriori(data,min_support=0.00001,use_colnames=True)

# %%
print(freq_itemset)
# Out:
#        support                        itemsets
# 0     0.000146                             (D)
# 1     0.000049                             (I)
# 2     0.000049                             (N)
# 3     0.000146                             (T)
# 4     0.000195                             (a)
# ...        ...                             ...
# 1240  0.000049     (a, T, i, o, N, t, r, n, s)
# 1241  0.000049     (T, i, o, N, c, t, r, n, s)
# 1242  0.000049     (a, i, o, N, c, t, r, n, s)
# 1243  0.000049     (a, T, i, o, c, t, r, n, s)
# 1244  0.000049  (a, T, i, o, N, c, t, r, n, s)
#
# [1245 rows x 2 columns]

# %%
len(te.columns_)
# Out:
# 16

# %%
#Find Rules

rules = association_rules(freq_itemset,metric = 'confidence',min_threshold=0.25)

# %%
rules = rules[['antecedents','consequents','antecedent support','support','confidence']]

# %%
rules
# Out:
#       antecedents                  consequents  antecedent support   support  \
# 0             (T)                          (D)            0.000146  0.000098
# 1             (D)                          (T)            0.000146  0.000098
# 2             (a)                          (D)            0.000195  0.000146
# 3             (D)                          (a)            0.000146  0.000146
# 4             (e)                          (D)            0.000146  0.000098
# ...           ...                          ...                 ...       ...
# 60129         (c)  (a, T, i, o, N, t, r, n, s)            0.000049  0.000049
# 60130         (t)  (a, T, i, o, N, c, r, n, s)            0.000195  0.000049
# 60131         (r)  (a, T, i, o, N, c, t, n, s)            0.000098  0.000049
# 60132         (n)  (a, T, i, o, N, c, t, r, s)            0.000049  0.000049
# 60133         (s)  (a, T, i, o, N, c, t, r, n)            0.000098  0.000049
#
#        confidence
# 0        0.666667
# ...

# %%
rules[rules['antecedents']=={'e'}]['consequents']
# Out:
# 4                       (D)
# 19                      (I)
# 49                      (T)
# 71                      (a)
# 103                     (i)
#                 ...
# 14004       (a, T, y, D, p)
# 14128       (T, i, D, t, m)
# 14190       (a, i, D, t, m)
# 23366       (a, T, i, t, m)
# 27460    (a, T, i, D, t, m)
# Name: consequents, Length: 99, dtype: object
